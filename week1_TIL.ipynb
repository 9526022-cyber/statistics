# %% [markdown]
# <a href="https://colab.research.google.com/github/9526022-cyber/scmscm/blob/main/week1_TIL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #3. 구글 코랩 사용법

# %%
seconds_in_a_day = 24*60*60
seconds_in_a_day
# Out:
# 86400

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# # 4.0.파이썬 소개
# ---

# %% [markdown]
# ## 파이썬의 특징
# - 오픈소스
# - 고수준 언어
# - 비교적 배우기 쉬움
# - 다양한 생태계-웹개발, 게임개발, 이미지. 영상. 데이터 사이언스 등
# - 커뮤니티
# - 건전지 포함-다양한 표준라이브러리
# - 접착제 언어-다른 언어와 호환이 잘 됨
# - 문서화
# - 블록 구조-들여쓰기를 사용하여 블록을 구분

# %% [markdown]
# #4.1.파이썬의 자료형
# ---
# ## 파이썬의 숫자와 기본연산

# %%
# import this를 출력해 봅니다.(Zen of Python)
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
# 정수 1을 출력해 봅니다.
1
# Out:
# 1

# %%
# 실수 1을 출력해 봅니다.
1.0
# Out:
# 1.0

# %%
# 정수 1의 타입을 출력해 봅니다.
type(1)
# Out:
# int

# %%
# 실수 1의 타입을 출력해 봅니다.
type(1.0)
# Out:
# float

# %%
# 더하기
1 + 2
# Out:
# 3

# %%
# 빼기
3 - 2
# Out:
# 1

# %%
# 곱하기
2 * 3
# Out:
# 6

# %%
# 나누기
3 / 2
# Out:
# 1.5

# %%
# 나누기 후 몫만 반환
3 // 2
# Out:
# 1

# %%
# 나누기 후 나머지만 반환
3 % 2
# Out:
# 1

# %%
# 정의되지 않은 변수를 출력해 보면 어떤 오류 메시지가 나오는지 확인해 봅니다.
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-579449845.py in <cell line: 0>()
#       1 # 정의되지 않은 변수를 출력해 보면 어떤 오류 메시지가 나오는지 확인해 봅니다.
# ----> 2 n
#
# NameError: name 'n' is not defined

# %%
width = 20
height = 5

width * height
# Out:
# 100

# %% [markdown]
# ## 파이썬 문자열

# %%
# 큰따옴표로 문자열을 정의합니다.
"파이썬"
# Out:
# '파이썬'

# %%
# 작은따옴표로 문자열을 정의합니다.
'파이썬'
# Out:
# '파이썬'

# %%
# 큰따옴표와 작은따옴표의 차이를 알아봅니다.
"파이썬's"
# Out:
# "파이썬's"

# %%
'파이썬\'s'
# Out:
# "파이썬's"

# %%
# 줄바꿈 문자를 표현합니다.
"""
줄바꿈
문자를
표현합니다.
"""
# Out:
# '\n줄바꿈\n문자를\n표현합니다.\n'

# %%
# *를 통해 문자를 반복 출력합니다.
"-" * 20
# Out:
# '--------------------'

# %%
# 변수에 담긴 문자열의 위치를 알아봅니다.
word = "Python's hobby?"
word
# Out:
# "Python's hobby?"

# %%
# 0번 인덱스의 원소를 가져옵니다.
word[0]
# Out:
# 'P'

# %%
# 1번 인덱스의 원소를 가져옵니다.
word[1]
# Out:
# 'y'

# %%
# 마지막 인덱스의 원소를 가져옵니다.
word[-1]
# Out:
# '?'

# %%
# [시작인덱스:끝나는인덱스+1]로 문자열의 일부를 가져옵니다.
# 앞에서 6개 글자만 가져옵니다.
word[0:6]
# Out:
# 'Python'

# %%
word[-6:]
# Out:
# 'hobby?'

# %%
word[:]
# Out:
# "Python's hobby?"

# %%
word[2:6]
# Out:
# 'thon'

# %%
# 소문자로 변환
word.lower()
# Out:
# "python's hobby?"

# %%
# 대문자로 변환
word.upper()
# Out:
# "PYTHON'S HOBBY?"

# %% [markdown]
# ## 문자열 리스트

# %%
squares = [1 ,4, 9, 16, 25]
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
type([])
# Out:
# list

# %%
# 인덱스 번호는 0부터 시작합니다.
squares[0]
# Out:
# 1

# %%
squares[-1]
# Out:
# 25

# %%
squares[-3]
# Out:
# 9

# %%
squares[:]
# Out:
# [1, 4, 9, 16, 25]

# %%
squares[:3]
# Out:
# [1, 4, 9]

# %%
squares[-3:]
# Out:
# [9, 16, 25]

# %%
# append로 값을 추가합니다.
squares.append(36)
squares
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
# remove로 값을 제거합니다.
squares.remove(36)
squares
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## 파이썬 딕셔너리

# %%
# {키:값} 형식
# 변수 '재고'에 고구마, 감자, 쪽파의 수량을 표시해 봅니다.

재고 = {'고구마': 4139, '감자': 4098, '쪽파': 100}
재고
# Out:
# {'고구마': 4139, '감자': 4098, '쪽파': 100}

# %%
type({})
# Out:
# dict

# %%
# 재고에 대파 추가
재고["대파"] = 345
재고
# Out:
# {'고구마': 4139, '감자': 4098, '쪽파': 100, '대파': 345}

# %%
재고["대파"]
# Out:
# 345

# %%
재고["양파"] = 643
재고
# Out:
# {'고구마': 4139, '감자': 4098, '쪽파': 100, '대파': 345, '양파': 643}

# %%
del 재고["양파"]
재고
# Out:
# {'고구마': 4139, '감자': 4098, '쪽파': 100, '대파': 345}

# %%
# dict를 list로 반환
list(재고)
# Out:
# ['고구마', '감자', '쪽파', '대파']

# %%
# sorted를 사용해 재고 변수에 담긴 딕셔너리의 키값을 기준으로 정렬
sorted(재고)
# Out:
# ['감자', '고구마', '대파', '쪽파']

# %%
재고.keys()
# Out:
# dict_keys(['고구마', '감자', '쪽파', '대파'])

# %%
재고.values()
# Out:
# dict_values([4139, 4098, 100, 345])

# %% [markdown]
# # 4.2. 파이썬의 제어문과 함수
# ---
# ## 파이썬 조건문

# %%
# 숫자를 입력받아 음수와 양수 여부를 출력합니다.
x = int(input("Please enter an integer: "))
if x > 0 :
    print("양수")
elif x == 0 :
    print("영")
else:
    print("음수")
# Out:
# Please enter an integer: 0
# 영

# %% [markdown]
# ## 파이썬 반복문
